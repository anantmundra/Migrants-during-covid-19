# %% [markdown]
# # <span style='background :beige'><span style='font-family:"Times New Roman"'>How will you get them the money?Security, Accessibility, Frequency, time to implement.</span>

# %% [markdown]
# ## <span style='background :bisque'><span style='font-family:"Times New Roman"'>Importing Necessary Libraries</span>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set()

# %% [markdown]
# ### <span style='background :wheat'><span style='font-family:"Times New Roman"'>India's Population: 1360 Million</span>

# %%
#India's Population: 1360 Million
data=pd.DataFrame()
data['Population Having Aadhar']=[1244400000]
data['Migrants Not Having Aadhar']=[115600000]
data.head()
# Out:
#    Population Having Aadhar  Migrants Not Having Aadhar
# 0                1244400000                   115600000

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
langs = ['Population Having Aadhar','Migrants Not Having Aadhar']
col = [1244400000,115600000]
ax.pie(col, labels = langs,autopct='%1.2f%%')
plt.title("Aadhar Status of India",size=18)
plt.show()

# %% [markdown]
# ![](aadhar-bank.jpg)

# %%
rank=pd.DataFrame()
rank['Security']=[2,1,3]
rank['Accessibility']=[1,2,3]
rank['Frequency of Access']=[2,3,1]
rank['Independece of control by person']=[3,2,1]
rank = rank.rename(index={0: 'Bank accounts',1:'Mobile money (wallet/crypto)',2:'One-time Deposit (post-office)'})
cm = sns.light_palette("burlywood", as_cmap=True)
rank.style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_6e247fd0_a73e_11ea_9cb1_e17455e20efcrow0_col0 {
#             background-color:  #ecd5b9;
#             color:  #000000;
#         }    #T_6e247fd0_a73e_11ea_9cb1_e17455e20efcrow0_col1 {
#             background-color:  #f9f3eb;
#             color:  #000000;
#         }    #T_6e247fd0_a73e_11ea_9cb1_e17455e20efcrow0_col2 {
#             background-color:  #ecd5b9;
#             color:  #000000;
#         }    #T_6e247fd0_a73e_11ea_9cb1_e17455e20efcrow0_col3 {
#             background-color:  #deb887;
#             color:  #000000;
#         }    #T_6e247fd0_a73e_11ea_9cb1_e17455e20efcrow1_col0 {
#             background-color:  #f9f3eb;
#             color:  #000000;
#         }    #T_6e247fd0_a73e_11ea_9cb1_e17455e20efcrow1_col1 {
#             background-color:  #ecd5b9;
#             color:  #000000;
#         }    #T_6e247fd0_a73e_11ea_9cb1_e17455e20efcrow1_col2 {
#             background-color:  #deb887;
#             color:  #000000;
# ...

# %% [markdown]
# ## <span style='background :bisque'><span style='font-family:"Times New Roman"'>SECURITY</span>
#
# <ol>
# <li>If ‘DIGITAL RUPEE’ were to be issued by RBI, it could address privacy and transparency concerns, providing benefits of cash as well.</li>
# <li>Online banking is the tempting target for hackers. Security is one of the problems faced by customers in accessing accounts through internet.</li>
# <li>Traditional banking does not encounter e-security threats.</li>
# <li>A cryptocurrency is a digital or virtual currency that is secured by cryptography, which makes it nearly impossible to counterfeit or double-spend. Many cryptocurrencies are decentralized networks based on blockchain technology—a distributed ledger enforced by a disparate network of computers.</li>
# <li>The main advantage would be crypto’s ability to function and operate without a single point of failure which hackers could target. Another vantage point is that as most of the cryptos are based on a P2P settlement system and are fully operational around the clock on holidays and weekends.</li>
# </ol>

# %% [markdown]
# ## <span style='background :bisque'><span style='font-family:"Times New Roman"'>ACCESSIBILITY (EASE OF ACCESS)</span>
# <ol>
# <li>Blockchain is the reason why cryptocurrency has any value. Ease of use is the reason why cryptocurrency is in high demand. All you need is a smart device, an internet connection and instantly you become your own bank making payments and money transfers.</li>
# <li>Making banking accessible is not just in the commercial interest of the bank but is also in line with its commitments under various legislation and international conventions. In India, this has even been acknowledged by RBI, which has issued a notification suggesting that at least onethird of the new ATMs of all banks must be accessible.</li>
# </ol>

# %% [markdown]
# ![](data.png)

# %% [markdown]
# ## <span style='background :bisque'><span style='font-family:"Times New Roman"'>FREQUENCY OF ACCESS</span>
# <ol>
# <li>To buy cryptocurrencies, you will need a “wallet,” an online app that can hold your currency.Generally, you create an account on an exchange, and then you can transfer real money to buy cryptocurrencies such as bitcoin or ethereum. Here's more on how to invest in bitcoin.</li>
# <li>Recently the State Bank of India (SBI) introduced a facility to withdraw cash via SBI YONO app without using a debit card.The PSU lender is not the only bank that offers such a
# facility; others like ICICI Bank and Axis Bank customers, too, can make cardless cash withdrawal
# albeit in a different manner. Now, although this is a convenient service, it has its limitations.
# </li>
# </ol>
#
#
#
#
# # Read more at:
#
# https://economictimes.indiatimes.com/wealth/save/heres-how-you-can-withdraw-cash-without-using-credit-or-debit-card-at-these-3-banks-atms/articleshow/68811216.cms?utm_source=contentofinterest&utm_medium=text&utm_campaign=cppst

# %% [markdown]
# ![](atm.png)

# %% [markdown]
# ## <span style='background :bisque'><span style='font-family:"Times New Roman"'>INDEPENDANCE OF CONTROL BY PERSON</span>
# <ol>
# <li>ATM use fees.</li>
# <li>The inability to withdraw cash if an ATM is broken.</li>
# <li>Potential for robbery.</li>
# <li>Potential for having your PIN hijacked by criminals manipulating an ATM.</li>
# <li>e-wallets still require to carry something.</li>
# </ol>

# %% [markdown]
# ![](bank_account.png)

# %% [markdown]
# <ol>
# <li>While the total number of verified virtual currency users stands at 1.7 million in India,
#   according to IAMAI.(The Internet & Mobile Association of India)</li>
# <li>As of 2018, only 7.6% of the population of India uses e-wallets[1]. This statistic shows
#   the under penetration of digital wallets in India and the scope of growth it offers. The
#   wallet space has been growing at a CAGR of nearly 30% for the past 3 years.</li>
# <li>Considering 200 million odd accounts have been added as part of financial includion plan
#   in 2014, 2015 (source - India goes postal in quest to open bank accounts for the masses)
#   we have approximately 550 million accounts which translate roughly into 400 million (40
#   crore) unique account holders.</li>
# </ol>

# %% [markdown]
# ## <span style='background :bisque'><span style='font-family:"Times New Roman"'>Bank Penetration</span>
# <ol>
# <li>While the total number of verified virtual currency users stands at 1.7 million in India,
#   according to IAMAI.(The Internet & Mobile Association of India)</li>
# <li>As of 2018, only 7.6% of the population of India uses e-wallets[1]. This statistic shows
#   the under penetration of digital wallets in India and the scope of growth it offers. The
#   wallet space has been growing at a CAGR of nearly 30% for the past 3 years.</li>
# <li>Considering 200 million odd accounts have been added as part of financial includion plan
#   in 2014, 2015 (source - India goes postal in quest to open bank accounts for the masses)
#   we have approximately 550 million accounts which translate roughly into 400 million (40
#   crore) unique account holders.</li>
# </ol>

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
langs = ['Bank Account Users','E-money/Wallets/Crypto-currency Users']
col = [400000000,100500000]
ax.pie(col, labels = langs,autopct='%1.2f%%')
plt.title("Bank Penetration India",size=18)
plt.show()

# %% [markdown]
# ## <span style='background :bisque'><span style='font-family:"Times New Roman"'>Mobile Penetration</span>
# <ol>
# <li>There are about 450 million smartphone users as compared to 550 million feature phone users in India.
#    About 40-45% of feature phone users own a device at less than Rs 1000.</li>
# </ol>

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
langs = ['Feature Phone Users','Smart Phone Users']
col = [550000000,450000000]
ax.pie(col, labels = langs,autopct='%1.2f%%')
plt.title("Mobile Penetration India",size=18)
plt.show()

# %% [markdown]
# ## <span style='font-family:"Times New Roman"'>India has the largest population of illiterate adults in the world – 287 million</span>
# ## <span style='font-family:"Times New Roman"'>Considering smart phone users less than feature phone phone even in 74% literacy rate.</span>
# ## <span style='font-family:"Times New Roman"'>Transfer of money to migrants via mobile wallets would be less feasible.

# %% [markdown]
# ## <span style='background-color:beige'><span style='font-family:"Times New Roman"'>SOLUTION

# %% [markdown]
# ## <span style='background-color:wheat'><span style='font-family:"Times New Roman"'>Most optimal way of tranferring money will be through bank accounts: as more than 90% of the population have Aadhar linked with the Bank Accounts.
